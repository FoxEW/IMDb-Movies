# %% [markdown]
# ![image.png](attachment:99235214-17c6-4452-8017-0f77248767e3.png)

# %% [markdown]
# # IMDb Movies Analysis and Predictions

# %% [markdown]
# ## Business Problem:
# For this project, you have been hired to produce a MySQL database on Movies from a subset of IMDB's publicly available dataset. Ultimately, you will use this database to analyze what makes a movie successful and will provide recommendations to the stakeholder on how to make a successful movie.

# %% [markdown]
# ### Source:
# #### https://datasets.imdbws.com/ .gz

# %% [markdown]
# We will focus on the following data files: <br>
# **title.basics.tsv.gz** <br>
# **title.ratings.tsv.gz** <br>
# **title.akas.tsv.gz** <br>

# %% [markdown]
# ### Part 4:
# ***
# #### Apply hypothesis testing to explore what makes a movie successful.
#
# For part 4 of the project, you will be using your MySQL database from part 3 to answer meaningful questions for your stakeholder. They want you to use your hypothesis testing and statistics knowledge to answer 3 questions about what makes a successful movie. <br>
#
# Questions to answer:
# The stakeholder's first question is: does the MPAA rating of a movie (G/PG/PG-13/R) affect how much revenue the movie generates. <br>
#
# They want you to perform a statistical test to get a mathematically-supported answer.
# They want you to report if you found a significant difference between ratings.
# If so, what was the p-value of your analysis?
# And which rating earns the most revenue?
# They want you to prepare a visualization that supports your finding.
# It is then up to you to think of 2 additional hypotheses to test that your stakeholder may want to know.
#
# Some example hypotheses you could test:
#
# Do movies that are over 2.5 hours long earn more revenue than movies that are 1.5 hours long (or less)?
# Do movies released in 2020 earn less revenue than movies released in 2018?
# How do the years compare for movie ratings?
# Do some movie genres earn more revenue than others?
# Are some genres higher rated than others?
# etc.
# Specifications
# Your Data
# A critical first step for this assignment will be to retrieve additional movie data to add to your SQL database.
# You will want to use the TMDB API again and extract data for additional years.
# You may want to review the optional lesson from Week 1 on "Using Glob to Load Many Files" to load and combine all of your API results for each year.
# However, trying to extract the TMDB data for all movies from 2000-2022 could take >24 hours!
# To address this issue, you should EITHER:
# Define a smaller (but logical) period of time to use for your analyses (e.g., last 10 years, 2010-2019 (pre-pandemic, etc).
# OR coordinate with cohort-mates and divide the API calls so that you can all download the data for a smaller number of years and then share your downloaded JSON data.

# %% [markdown]
# ## **Load the Data**

# %% [markdown]
# - #### Import Libraries and JSON File**

# %%
# Standard imports
import pandas as pd
import numpy as np
import os, json, math, time
from tqdm.notebook import tqdm_notebook
import scipy.stats as stats
import glob
pd.set_option('display.max_columns',100)

# Import Api
import tmdbsimple as tmdb 

import matplotlib.pyplot as plt
import seaborn as sns

import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists
from sqlalchemy.types import *

FOLDER = "Data/"

# %%
# Create connection string using credentials following this format
# Connection = "dialect+driver://username:password@host:port/database"
username = "root"
password = "root" 
db_name = "movies"
connection = f"mysql+pymysql://{username}:{password}@localhost/{db_name}"

# Create the engine
engine = create_engine(connection)

# Check if the database exists. If not, create it.
if database_exists(connection) == False:
  create_database(connection)
else:
  print('The database already exists')

# Verify that the database was created
database_exists(connection)
# Out:
# The database already exists
# True

# %% [markdown]
# - #### **Defining Functions for API Calls**

# %%
# Access tmdb api
#movie_id = tmdb.Movies('imdb_id')

# Creating function for movie rating
def get_movie_with_rating(movie_id):
    movie = tmdb.Movies(movie_id)
    info = movie.info()
    
    releases = movie.releases()
    for c in releases['countries']:
        if c['iso_3166_1']=='US':
            info['certification'] = c['certification']
            
    return info

# %%
# Create function to make json files
def write_json(new_data, filename): 
    """Appends a list of records (new_data) to a json file (filename). 
    Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/"""  
    
    with open(filename,'r+') as file:
        # First we load existing data into a dict.
        file_data = json.load(file)
        
        ## Choose extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
            
        # Sets file's current position at offset.
        file.seek(0)
        
        # convert back to json.
        json.dump(file_data, file)

# %% [markdown]
# - #### **Using Your API Credentials**

# %%
with open('/Users/Erfoxcroft/.secret/tmdb_api.json', 'r') as f:

    login = json.load(f)

tmdb.API_KEY =  login['api-key']

# %% [markdown]
# - #### **Load in the Title Basics data**

# %%
# Load in the dataframe from project part 1 as basics:
basics = pd.read_csv(f'{FOLDER}title_basics.csv.gz')

# %%
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0082328     movie                                 Embodiment of Evil
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                      Encarnação do Demônio        0     2008.0      NaN
# 4                          The Naked Monster        0     2005.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3              94                  Horror
# 4             100    Comedy,Horror,Sci-Fi

# %%
YEARS_TO_GET = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019]
errors = []

# %% [markdown]
# - #### **Create Required Lists for the Loop**

# %%
# Organize output by year into separate .json files using an OUTER LOOP

# Start of OUTER loop
for YEAR in tqdm_notebook(YEARS_TO_GET, desc='YEARS', position=0):
    # Defining the JSON file to store results for the year
    JSON_FILE = f'{FOLDER}tmdb_api_results_{YEAR}.json'
    
    # Check if the file exists
    file_exists = os.path.isfile(JSON_FILE)
    
    # If it does not exist: create it
    if not file_exists:  # Simplified condition
        # Save an empty dict with just "imdb_id" to the new json file.
        with open(JSON_FILE, 'w') as f:
            json.dump([{'imdb_id': 0}], f)

    # Saving the new year as the current df
    df = basics.loc[basics['startYear'] == YEAR].copy()
    # Saving movie ids to list
    movie_ids = df['tconst'].copy()

    # Load existing data from json into a dataframe called "previous_df"
    previous_df = pd.read_json(JSON_FILE)

    # Filter out any ids that are already in the JSON_FILE
    movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]

    # Get index and movie id from the list

 # Develop code to make API calls based on our existing IMDB IDs with the INNER Loop   
    # INNER Loop
    for movie_id in tqdm_notebook(movie_ids_to_get,
                                  desc=f'Movies from {YEAR}',
                                  position=1,
                                  leave=True):
        try:
            # Retrieve the data for the movie id
            temp = get_movie_with_rating(movie_id)
            # Append/extend results to the existing file using a pre-made function
            write_json(temp, JSON_FILE)
            # Short 20 ms sleep to prevent overwhelming the server
            time.sleep(0.02)

        except Exception as e:
            errors.append([movie_id, e])

    final_year_df = pd.read_json(JSON_FILE)
    final_year_df.to_csv(f"{FOLDER}final_tmdb_data_{YEAR}.csv.gz", compression="gzip", index=False)
# Out:
# YEARS:   0%|          | 0/1 [00:00<?, ?it/s]
# Movies from 2019:   0%|          | 0/5898 [00:00<?, ?it/s]

# %% [markdown]
# - #### **Read in Files and Merge with glob"**

# %%
# Make a filepath query
q = 'Data/final*.csv.gz'
file_list = sorted(glob.glob(q))
file_list
# Out:
# ['Data\\final_tmdb_data_2001.csv.gz',
#  'Data\\final_tmdb_data_2002.csv.gz',
#  'Data\\final_tmdb_data_2010.csv.gz',
#  'Data\\final_tmdb_data_2011.csv.gz',
#  'Data\\final_tmdb_data_2012.csv.gz',
#  'Data\\final_tmdb_data_2013.csv.gz',
#  'Data\\final_tmdb_data_2014.csv.gz',
#  'Data\\final_tmdb_data_2015.csv.gz',
#  'Data\\final_tmdb_data_2016.csv.gz',
#  'Data\\final_tmdb_data_2017.csv.gz',
#  'Data\\final_tmdb_data_2018.csv.gz',
#  'Data\\final_tmdb_data_2019.csv.gz']

# %%
# Use glob.glob to get COMPLETE filepaths
q = "Data/**/final*.csv.gz"
file_list = sorted(glob.glob(q,recursive=True))
file_list
# Out:
# ['Data\\final_tmdb_data_2001.csv.gz',
#  'Data\\final_tmdb_data_2002.csv.gz',
#  'Data\\final_tmdb_data_2010.csv.gz',
#  'Data\\final_tmdb_data_2011.csv.gz',
#  'Data\\final_tmdb_data_2012.csv.gz',
#  'Data\\final_tmdb_data_2013.csv.gz',
#  'Data\\final_tmdb_data_2014.csv.gz',
#  'Data\\final_tmdb_data_2015.csv.gz',
#  'Data\\final_tmdb_data_2016.csv.gz',
#  'Data\\final_tmdb_data_2017.csv.gz',
#  'Data\\final_tmdb_data_2018.csv.gz',
#  'Data\\final_tmdb_data_2019.csv.gz']

# %%
# Use a list comprehension to load in all files into 1 dataframe
df = pd.concat([pd.read_csv(f,lineterminator='\n') for f in file_list])
df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0035423    0.0  /tJLV3BAlHOgscVOrA99Wnb2gAef.jpg
# 2     tt0114447    0.0                               NaN
# 3     tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg
# 4     tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg
# ...         ...    ...                               ...
# 4932  tt9906644    0.0  /htoReVItKtolso5VJqFqJDBaOwm.jpg
# 4933  tt9913660    0.0   /z6YpkQiWLnRKl5yQD9dSiPDFWN.jpg
# 4934  tt9913872    0.0  /a0kySBmMZ77AqmNA3pDu45GsbCp.jpg
# 4935  tt9914942    0.0  /tjHUeULyw2vtS1DXFp0OHfhUzRX.jpg
# 4936  tt9915872    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  48000000.0
# 2                      NaN         0.0
# 3                      NaN  22000000.0
# 4                      NaN   1000000.0
# ...                    ...         ...
# 4932                   NaN         0.0
# 4933                   NaN         0.0
# 4934                   NaN         0.0
# 4935                   NaN         0.0
# 4936                   NaN         0.0
#
#                                                  genres homepage        id  \
# 0                                                   NaN      NaN       NaN
# 1     [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN   11232.0
# 2     [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN  151007.0
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN   10696.0
# 4     [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN   17140.0
# ...                                                 ...      ...       ...
# 4932  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  635903.0
# 4933                      [{'id': 18, 'name': 'Drama'}]      NaN  711261.0
# 4934                     [{'id': 27, 'name': 'Horror'}]      NaN  800030.0
# 4935  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN  598553.0
# 4936                                                 []      NaN  897433.0
#
#      original_language              original_title  \
# 0                  NaN                         NaN
# 1                   en              Kate & Leopold
# 2                   en            The Silent Force
# 3                   en                     Glitter
# 4                   en       The Attic Expeditions
# ...                ...                         ...
# 4932                ml                      മനോഹരം
# 4933                en                  No Apology
# 4934                es       De la piel del Diablo
# 4935                ca  La vida sense la Sara Amat
# 4936                en        The Last White Witch
#
#                                                overview  popularity  \
# 0                                                   NaN         NaN
# 1     When her scientist ex-boyfriend discovers a po...      16.406
# 2     An elite Federal force whose objective is to e...       1.657
# 3     A young woman is catapulted into pop stardom, ...       9.430
# 4     Trevor Blackburn is accused of murdering his g...       5.259
# ...                                                 ...         ...
# 4932  Manoharan is a poster artist struggling to fin...       3.599
# 4933  When a group of women struggle to deal with th...       1.132
# 4934                                                NaN       0.788
# 4935  Pep, a 13-year-old boy, is in love with a girl...      19.557
# 4936  One day, a charming and mystical girl, Fuka, a...       0.600
#
#                            poster_path  \
# 0                                  NaN
# 1     /mUvikzKJJSg9khrVdxK8kg3TMHA.jpg
# 2     /u0njmfXD3dXxQfeykBHBuFQOYqD.jpg
# 3     /b8gKsXB6d60SC2HKUcAAzTacn0S.jpg
# 4     /b0p8CjMLWc7B1nnIfFQ2uY3HLe0.jpg
# ...                                ...
# 4932  /cNWfJlveyMEbiORrKmFKZZRDx75.jpg
# 4933  /fqIWD97MAjgrj8mB2M78kxeSSnk.jpg
# 4934  /it2z2X2pxeurP1Cmzo5C3BJdQ2W.jpg
# 4935  /ulCLv5kRiC8JnxdRBczDzx0NjSr.jpg
# 4936                               NaN
#
#                                    production_companies  \
# 0                                                   NaN
# 1     [{'id': 85, 'logo_path': None, 'name': 'Konrad...
# 2                                                    []
# 3     [{'id': 89627, 'logo_path': None, 'name': 'Gli...
# 4     [{'id': 3260, 'logo_path': None, 'name': 'Tse ...
# ...                                                 ...
# 4932  [{'id': 125107, 'logo_path': None, 'name': 'Ch...
# 4933                                                 []
# 4934                                                 []
# 4935  [{'id': 20786, 'logo_path': None, 'name': "Mas...
# 4936                                                 []
#
#                                    production_countries release_date  \
# 0                                                   NaN          NaN
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...   2001-12-25
# 2                                                    []   2001-01-01
# 3     [{'iso_3166_1': 'US', 'name': 'United States o...   2001-09-21
# 4     [{'iso_3166_1': 'US', 'name': 'United States o...   2001-03-30
# ...                                                 ...          ...
# 4932            [{'iso_3166_1': 'IN', 'name': 'India'}]   2019-09-27
# 4933                                                 []   2019-10-23
# 4934                                                 []   2019-01-01
# 4935            [{'iso_3166_1': 'ES', 'name': 'Spain'}]   2019-07-12
# 4936                                                 []          NaN
#
#          revenue  runtime                                   spoken_languages  \
# 0            NaN      NaN                                                NaN
# 1     76019048.0    118.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 2            0.0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3      5271666.0    104.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4            0.0    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...          ...      ...                                                ...
# 4932         0.0    122.0  [{'english_name': 'Malayalam', 'iso_639_1': 'm...
# 4933         0.0    102.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4934         0.0      0.0                                                 []
# 4935         0.0     71.0  [{'english_name': 'Catalan', 'iso_639_1': 'ca'...
# 4936         0.0     97.0                                                 []
#
#         status                                            tagline  \
# 0          NaN                                                NaN
# 1     Released  If they lived in the same century, they'd be p...
# 2     Released  They left him for dead... They should have fin...
# 3     Released   In music she found her dream, her love, herself.
# 4     Released  His search for peace of mind... will leave his...
# ...        ...                                                ...
# 4932  Released                                                NaN
# 4933  Released                                                NaN
# 4934  Released                                                NaN
# 4935  Released                                                NaN
# 4936  Released                                                NaN
#
#                        title  video  vote_average  vote_count certification\r
# 0                        NaN    NaN           NaN         NaN              \r
# 1             Kate & Leopold    0.0         6.324      1241.0         PG-13\r
# 2           The Silent Force    0.0         5.000         3.0              \r
# 3                    Glitter    0.0         4.405       132.0         PG-13\r
# 4      The Attic Expeditions    0.0         5.156        32.0             R\r
# ...                      ...    ...           ...         ...             ...
# 4932               Manoharam    0.0         6.042        12.0              \r
# 4933              No Apology    0.0         8.000         1.0              \r
# 4934   De la piel del Diablo    0.0         8.200         3.0              \r
# 4935  Life without Sara Amat    0.0         7.700         8.0              \r
# 4936    The Last White Witch    0.0         0.000         0.0              \r
#
# [41298 rows x 26 columns]

# %% [markdown]
# ## **Clean and Prepare the Data**

# %%
# Remove character "/r" from column name
df.rename(columns={'certification\r':'certification'}, inplace=True)

# Remove character "/r" from data in column
df['certification']=df['certification'].replace({"\r": ""},regex=True)

# Fill missing spaces
df['certification'] = df['certification'].replace({'':np.nan})

df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /tJLV3BAlHOgscVOrA99Wnb2gAef.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
# 4  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
# 4   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN
#
#          id original_language         original_title  \
# 0       NaN               NaN                    NaN
# 1   11232.0                en         Kate & Leopold
# 2  151007.0                en       The Silent Force
# 3   10696.0                en                Glitter
# 4   17140.0                en  The Attic Expeditions
#
#                                             overview  popularity  \
# 0                                                NaN         NaN
# 1  When her scientist ex-boyfriend discovers a po...      16.406
# 2  An elite Federal force whose objective is to e...       1.657
# 3  A young woman is catapulted into pop stardom, ...       9.430
# 4  Trevor Blackburn is accused of murdering his g...       5.259
#
#                         poster_path  \
# 0                               NaN
# 1  /mUvikzKJJSg9khrVdxK8kg3TMHA.jpg
# 2  /u0njmfXD3dXxQfeykBHBuFQOYqD.jpg
# 3  /b8gKsXB6d60SC2HKUcAAzTacn0S.jpg
# 4  /b0p8CjMLWc7B1nnIfFQ2uY3HLe0.jpg
#
#                                 production_companies  \
# 0                                                NaN
# 1  [{'id': 85, 'logo_path': None, 'name': 'Konrad...
# 2                                                 []
# 3  [{'id': 89627, 'logo_path': None, 'name': 'Gli...
# 4  [{'id': 3260, 'logo_path': None, 'name': 'Tse ...
#
#                                 production_countries release_date     revenue  \
# 0                                                NaN          NaN         NaN
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2001-12-25  76019048.0
# 2                                                 []   2001-01-01         0.0
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...   2001-09-21   5271666.0
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   2001-03-30         0.0
#
#    runtime                                   spoken_languages    status  \
# 0      NaN                                                NaN       NaN
# 1    118.0  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# 2     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3    104.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                  title  \
# 0                                                NaN                    NaN
# 1  If they lived in the same century, they'd be p...         Kate & Leopold
# 2  They left him for dead... They should have fin...       The Silent Force
# 3   In music she found her dream, her love, herself.                Glitter
# 4  His search for peace of mind... will leave his...  The Attic Expeditions
#
#    video  vote_average  vote_count certification
# 0    NaN           NaN         NaN           NaN
# 1    0.0         6.324      1241.0         PG-13
# 2    0.0         5.000         3.0           NaN
# 3    0.0         4.405       132.0         PG-13
# 4    0.0         5.156        32.0             R

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41298 entries, 0 to 4936
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                41298 non-null  object
#  1   adult                  41286 non-null  float64
#  2   backdrop_path          27507 non-null  object
#  3   belongs_to_collection  2834 non-null   object
#  4   budget                 41286 non-null  float64
#  5   genres                 41286 non-null  object
#  6   homepage               10353 non-null  object
#  7   id                     41286 non-null  float64
#  8   original_language      41286 non-null  object
#  9   original_title         41286 non-null  object
#  10  overview               40434 non-null  object
#  11  popularity             41286 non-null  float64
#  12  poster_path            38411 non-null  object
#  13  production_companies   41286 non-null  object
#  14  production_countries   41286 non-null  object
#  15  release_date           40638 non-null  object
#  16  revenue                41286 non-null  float64
#  17  runtime                41286 non-null  float64
#  18  spoken_languages       41286 non-null  object
#  19  status                 41286 non-null  object
#  20  tagline                15383 non-null  object
#  21  title                  41286 non-null  object
#  22  video                  41286 non-null  float64
#  23  vote_average           41286 non-null  float64
#  24  vote_count             41286 non-null  float64
#  25  certification          8764 non-null   object
# dtypes: float64(9), object(17)
# memory usage: 8.5+ MB

# %%
df['certification'].value_counts()
# Out:
# R          3344
# NR         2343
# PG-13      1824
# PG          858
# G           288
# NC-17       101
# Unrated       4
# PG-13         2
# Name: certification, dtype: int64

# %% [markdown]
# - #### **Remove/Drop Rows**

# %%
# Remove rows where imdb_id = "0"
df = df[df['imdb_id'].str.contains('0')==False]

df['imdb_id'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 18218 entries, 1313 to 4936
# Series name: imdb_id
# Non-Null Count  Dtype
# --------------  -----
# 18218 non-null  object
# dtypes: object(1)
# memory usage: 284.7+ KB

# %%
# Drop rows where Null values exist in certification
df = df.dropna(subset=['certification'])

# Check null values
null_values = df.isna().sum()
null_values
# Out:
# imdb_id                     0
# adult                       0
# backdrop_path             743
# belongs_to_collection    3345
# budget                      0
# genres                      0
# homepage                 2218
# id                          0
# original_language           0
# original_title              0
# overview                    7
# popularity                  0
# poster_path               129
# production_companies        0
# production_countries        0
# release_date                0
# revenue                     0
# runtime                     0
# spoken_languages            0
# status                      0
# tagline                  1283
# title                       0
# video                       0
# vote_average                0
# vote_count                  0
# certification               0
# dtype: int64

# %%
df['release_date'].dtype
# Out:
# dtype('O')

# %%
# Convert to datetime using pd.to_datetime
df['release_year'] = pd.to_datetime(df['release_date']).dt.to_period('Y')
df.head()
# Out:
#         imdb_id  adult                     backdrop_path  \
# 1362  tt8795764    0.0                               NaN
# 1266  tt1485691    0.0                               NaN
# 1267  tt1513854    0.0  /3r56SV6WjnKIx7uUUWeXZN23n4p.jpg
# 216   tt1123373    0.0  /af3gx7Tuu08pf8ioJU0ok6r407J.jpg
# 217   tt1125929    0.0  /6HT2Ep7riT2gOf9atuxW6gOY13G.jpg
#
#                                   belongs_to_collection      budget  \
# 1362                                                NaN         0.0
# 1266                                                NaN         0.0
# 1267                                                NaN         0.0
# 216   {'id': 222639, 'name': 'Detective Dee Collecti...  13000000.0
# 217                                                 NaN         0.0
#
#                                                  genres  \
# 1362                     [{'id': 27, 'name': 'Horror'}]
# 1266                     [{'id': 27, 'name': 'Horror'}]
# 1267  [{'id': 35, 'name': 'Comedy'}, {'id': 9648, 'n...
# 216   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 217                       [{'id': 18, 'name': 'Drama'}]
#
#                                                homepage         id  \
# 1362  https://www.utahwolf.com/films/coming-soon-new...   871624.0
# 1266                                                NaN   406849.0
# 1267                                                NaN  1175791.0
# 216                                                 NaN    48492.0
# 217                                                 NaN    39845.0
#
#      original_language                                     original_title  \
# 1362                en                                          New Breed
# 1266                en                                              Charm
# 1267                en  Peter Meadowdale: Big Crimes, Big City, Short ...
# 216                 zh                                           狄仁傑之通天帝國
# 217                 en                                         Love Ranch
#
#                                                overview  popularity  \
# 1362  Derek gets sucked into a gothic cult that turn...       1.091
# 1266  Underground filmmakers Sarah Reed and Sadie Sh...       0.600
# 1267  It is one week since Meadowdale's run-in with ...       0.600
# 216   When the future empress Wu Zetian's two courti...      18.844
# 217   Story of a couple that starts the first legal ...       7.750
#
#                            poster_path  \
# 1362  /goddglRmgDgQuo9tlMdoeeHlRfX.jpg
# 1266                               NaN
# 1267  /2LNsEE2BwhhojMahoGvk7kF9ujc.jpg
# 216   /qWOBV05kNeLyaiA31DFkZlMpta5.jpg
# 217   /5Br0vFwX5UJZ60hwmSMMIKH2RgZ.jpg
#
#                                    production_companies  \
# 1362  [{'id': 133614, 'logo_path': None, 'name': 'Wo...
# 1266                                                 []
# 1267  [{'id': 208173, 'logo_path': None, 'name': 'Li...
# 216   [{'id': 3393, 'logo_path': None, 'name': 'Huay...
# 217   [{'id': 826, 'logo_path': None, 'name': 'Capit...
#
#                                    production_countries release_date  \
# 1362  [{'iso_3166_1': 'US', 'name': 'United States o...   2001-01-01
# 1266                                                 []   2002-01-25
# 1267                                                 []   2002-05-31
# 216   [{'iso_3166_1': 'CN', 'name': 'China'}, {'iso_...   2010-09-18
# 217   [{'iso_3166_1': 'US', 'name': 'United States o...   2010-06-30
#
#          revenue  runtime                                   spoken_languages  \
# 1362         0.0     57.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 1266         0.0     70.0                                                 []
# 1267         0.0     47.0                                                 []
# 216   51723285.0    123.0  [{'english_name': 'Mandarin', 'iso_639_1': 'zh...
# 217          0.0    117.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#         status                                            tagline  \
# 1362  Released                                                NaN
# 1266  Released                                                NaN
# 1267  Released  Enter a world where crime doesn't pay......unt...
# 216   Released             The Fate of an Empire Is in His Hands.
# 217   Released    When It Comes To Love... Everyone Pays A Price.
#
#                                                   title  video  vote_average  \
# 1362                                          New Breed    0.0         0.000
# 1266                                              Charm    0.0         0.000
# 1267  Peter Meadowdale: Big Crimes, Big City, Short ...    0.0         0.000
# 216   Detective Dee and the Mystery of the Phantom F...    0.0         6.569
# 217                                          Love Ranch    0.0         5.457
#
#       vote_count certification release_year
# 1362         0.0            NR         2001
# 1266         0.0            NR         2002
# 1267         0.0            NR         2002
# 216        360.0         PG-13         2010
# 217         47.0             R         2010

# %% [markdown]
# ## **Output to CSV and write to Mysql database**

# %% [markdown]
# - #### **Output to CSV**

# %%
# Specify the path for the output concatenated CSV file
output_csv_path = "Data/extended_year_tmdb_results_combined.csv"

# Save the concatenated DataFrame to a new CSV file
df.to_csv(output_csv_path, index=False)

# %% [markdown]
# - #### **Write a selection of columns to MySQL database**

# %%
extended_tmdb_data = df[['imdb_id','revenue','budget','certification','release_year']]

# %%
extended_tmdb_data.head(5)
# Out:
#         imdb_id     revenue      budget certification release_year
# 1362  tt8795764         0.0         0.0            NR         2001
# 1266  tt1485691         0.0         0.0            NR         2002
# 1267  tt1513854         0.0         0.0            NR         2002
# 216   tt1123373  51723285.0  13000000.0         PG-13         2010
# 217   tt1125929         0.0         0.0             R         2010

# %%
key_len1 = extended_tmdb_data['imdb_id'].fillna('').map(len).max()
cert_len = extended_tmdb_data['certification'].fillna('').map(len).max()

## Create a schema dictonary using Sqlalchemy datatype objects
extended_tmdb_data_schema = {
                                "imdb_id": String(key_len1+1), 
                                "certification": Text(cert_len+1),
                                'revenue':Float(),
                                'budget':Float(),
                                'relase_year':Date()}

# %%
extended_tmdb_data.to_sql('extended_tmdb_data' ,engine ,dtype=extended_tmdb_data_schema ,if_exists='replace' ,index=False)
# Out:
# 3803

# %%
engine.execute('ALTER TABLE extended_tmdb_data ADD PRIMARY KEY (`imdb_id`);')

# %% [markdown]
# ## **Hypothesis Testing**

# %% [markdown]
# - #### **Hypothesis 1:**

# %% [markdown]
# > Null Hypothesis: There is no significant difference in revenue regardless of MPAA Ratings.
# >
# > Alternative Hypothesis: There is a significant difference in revenue based on the MPAA Ratings.
# >
# > Using an alpha=.05

# %%
# Select data from MySQL
q = """SELECT *
FROM extended_tmdb_data"""
pd.read_sql(q, engine)
# Out:
#          imdb_id  revenue  budget certification release_year
# 0     tt11127382      0.0     0.0             G         2019
# 1     tt11135936      0.0     0.0             R         2019
# 2     tt11162126      0.0     0.0            NR         2019
# 3      tt1117668      0.0     0.0             R         2010
# 4     tt11191124      0.0     0.0            NR         2019
# ...          ...      ...     ...           ...          ...
# 3798   tt9826668      0.0     0.0             G         2019
# 3799   tt9831136      0.0     0.0             R         2019
# 3800   tt9844368      0.0     0.0            PG         2019
# 3801   tt9887154      0.0     0.0            NR         2021
# 3802   tt9896916      0.0     0.0            PG         2019
#
# [3803 rows x 5 columns]

# %%
df_rating = pd.read_sql_query(q, engine)

# %%
# Create groups dictionary. There are only 3 groups, but this is even more helpful when there are many groups
groups = {}

# Loop through all unique categories
for i in df_rating['certification'].unique():
    
    # Get series for group and rename
    data = df_rating.loc[df_rating['certification'] == i, 'revenue'].copy()

    # Check if the group has at least 8 samples
    if len(data) >= 1:
        
        # Save into the dictionary
        groups[i] = data
        
groups.keys()
# Out:
# dict_keys(['G', 'R', 'NR', 'PG-13', 'PG', 'NC-17', 'Unrated'])

# %% [markdown]
# #### **Testing Assumptions - ANOVA**

# %% [markdown]
# >**Assumption of Normality**

# %%
# Running normal test on each group and confirming there are >20 in each group
norm_results = {}
for i, data in groups.items():
    stat, p = stats.normaltest(data)
    
    ## save the p val, test statistic, and the size of the group
    norm_results[i] = {'n': len(data),
                             'p':p,
                             'test stat':stat,}
    
## Convert to a dataframe
norm_results_df = pd.DataFrame(norm_results).T
norm_results_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 4
#       2 norm_results = {}
#       3 for i, data in groups.items():
# ----> 4     stat, p = stats.normaltest(data)
#       6     ## save the p val, test statistic, and the size of the group
#       7     norm_results[i] = {'n': len(data),
#       8                              'p':p,
#       9                              'test stat':stat,}
#
# File ~\AppData\Local\anaconda3\envs\dojo-env\lib\site-packages\scipy\stats\_stats_py.py:1833, in normaltest(a, axis, nan_policy)
#    1830     a = ma.masked_invalid(a)
#    1831     return mstats_basic.normaltest(a, axis)
# -> 1833 s, _ = skewtest(a, axis)
#    1834 k, _ = kurtosistest(a, axis)
#    1835 k2 = s*s + k*k
#
# File ~\AppData\Local\anaconda3\envs\dojo-env\lib\site-packages\scipy\stats\_stats_py.py:1636, in skewtest(a, axis, nan_policy, alternative)
#    1634 n = a.shape[axis]
#    1635 if n < 8:
# -> 1636     raise ValueError(
#    1637         "skewtest is not valid with less than 8 samples; %i samples"
#    1638         " were given." % int(n))
#    1639 y = b2 * math.sqrt(((n + 1) * (n + 3)) / (6.0 * (n - 2)))
#    1640 beta2 = (3.0 * (n**2 + 27*n - 70) * (n+1) * (n+3) /
#    1641          ((n-2.0) * (n+5) * (n+7) * (n+9)))
#
# ValueError: skewtest is not valid with less than 8 samples; 1 samples were given.

# %%
# checking sig with pandas 
norm_results_df['sig'] = norm_results_df['p'] < .05 
norm_results_df
# Out:
#                 n              p    test stat    sig
# Action      788.0  1.353853e-200   920.428128   True
# Adult        15.0            NaN          NaN  False
# Adventure   501.0   2.628836e-99   453.978766   True
# Animation   268.0   3.438669e-52   236.998680   True
# Biography   145.0   4.803116e-49   222.514809   True
# Comedy     1137.0  3.685520e-290  1332.890531   True
# Crime       489.0  2.035717e-124   569.619407   True
# Drama      1841.0   0.000000e+00  3938.113010   True
# Family      224.0   2.042175e-77   353.170073   True
# Fantasy     216.0   3.188488e-54   246.360096   True
# History      89.0   1.577215e-22   100.402422   True
# Horror      839.0  6.013924e-301  1382.568071   True
# Music        83.0   2.317202e-30   136.474385   True
# Musical      37.0   3.533044e-18    80.368744   True
# Mystery     320.0   5.104744e-86   392.784296   True
# Romance     428.0  3.894096e-107   490.034287   True
# Sci-Fi      265.0   1.150138e-58   266.820108   True
# Sport        60.0   2.229406e-22    99.710274   True
# Thriller    745.0  4.344937e-211   968.752887   True
# War          42.0   1.081876e-12    55.104650   True
# Western      31.0   1.049512e-16    73.586073   True

# %% [markdown]
# >**Assumption of Equal Variance**

# %%
# with the * operator 
stats.levene(*groups.values())
# Out:
# LeveneResult(statistic=33.53946026555663, pvalue=1.2293254428645416e-39)

# %% [markdown]
# The low p-value indicates that the assumption of equal variance have not been met.

# %% [markdown]
# #### **One-Way ANOVA Test**

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# save the values as kg_lost and the labels to the Diet
values = df_rating['revenue']
labels = df_rating['certification']

# %%
# perform tukey's multiple comparison test and display the summary
tukeys_results = pairwise_tukeyhsd(values,labels)
tukeys_results.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# - The Reject True value indicates a result to reject null hypothesis

# %% [markdown]
# #### **Visual**

# %%
sns.barplot(data=df_rating, x='certification',y='revenue');

# %% [markdown]
# - Movies in the PG-13 category earn the most revenue when compared to other certification types

# %% [markdown]
# - #### **Hypothesis 2:**

# %% [markdown]
# > Null Hypothesis: There is no significant difference in budget allocation in movies release year between 2018 and 2019.
# >
# > Alternative Hypothesis: There is a significant difference in budget allocation between movies release year 2018 and 2019.
# >
# > Using an alpha=.05

# %% [markdown]
# >**Assumption of Independent T-Test**

# %% [markdown]
# >- No significant outliers
# >- Normality
# >- Equial Variance

# %%
df_rating.head()
# Out:
#       imdb_id  revenue  budget certification release_year
# 0  tt11127382      0.0     0.0             G         2019
# 1  tt11135936      0.0     0.0             R         2019
# 2  tt11162126      0.0     0.0            NR         2019
# 3   tt1117668      0.0     0.0             R         2010
# 4  tt11191124      0.0     0.0            NR         2019

# %%
release_2018 = df_rating.loc[df_rating['release_year']== '2018',"budget"]
release_2018
# Out:
# 41        100000.0
# 96             0.0
# 119            0.0
# 135     42000000.0
# 139     30000000.0
#            ...
# 3765           0.0
# 3766      500000.0
# 3774           0.0
# 3781           0.0
# 3796        1000.0
# Name: budget, Length: 394, dtype: float64

# %%
release_2019 = df_rating.loc[df_rating['release_year']== '2019',"budget"]
release_2019
# Out:
# 0          0.0
# 1          0.0
# 2          0.0
# 4          0.0
# 7       5000.0
#          ...
# 3797       0.0
# 3798       0.0
# 3799       0.0
# 3800       0.0
# 3802       0.0
# Name: budget, Length: 353, dtype: float64

# %% [markdown]
# >**Testing for Outliers**

# %%
zscores_f = stats.zscore(release_2018)
outliers_f = abs(zscores_f)>3
np.sum(outliers_f)
# Out:
# 10

# %%
zscores_f = stats.zscore(release_2019)
outliers_f = abs(zscores_f)>3
np.sum(outliers_f)
# Out:
# 7

# %% [markdown]
# >**Test Each Group for Normality**

# %%
# normal test release_2018
result_2018 = stats.normaltest(release_2018)
result_2018
# Out:
# NormaltestResult(statistic=436.6676348809208, pvalue=1.5094817711000585e-95)

# %%
# normal test release_2019
result_2019 = stats.normaltest(release_2019)
result_2019
# Out:
# NormaltestResult(statistic=442.50165016910603, pvalue=8.165589611422271e-97)

# %% [markdown]
# >**Testing for Equal Variance with Levene's test**

# %%
result = stats.levene(release_2018, release_2019)
result
# Out:
# LeveneResult(statistic=0.030267128487112126, pvalue=0.8619327605210177)

# %% [markdown]
# >**Perform and evaluate the t-test**

# %%
result2 = stats.ttest_ind(release_2018, release_2019, equal_var = False)
result2
# Out:
# Ttest_indResult(statistic=0.17375170739474818, pvalue=0.8621086376846268)

# %% [markdown]
# >**Visual**

# %%
q = """SELECT *
FROM
    extended_tmdb_data
WHERE
    release_year IN (2018, 2019);
"""
pd.read_sql(q, engine)
# Out:
#         imdb_id  revenue  budget certification release_year
# 0    tt11127382      0.0     0.0             G         2019
# 1    tt11135936      0.0     0.0             R         2019
# 2    tt11162126      0.0     0.0            NR         2019
# 3    tt11191124      0.0     0.0            NR         2019
# 4    tt11219342      0.0  5000.0         PG-13         2019
# ..          ...      ...     ...           ...          ...
# 742   tt9826484  15712.0     0.0             R         2019
# 743   tt9826668      0.0     0.0             G         2019
# 744   tt9831136      0.0     0.0             R         2019
# 745   tt9844368      0.0     0.0            PG         2019
# 746   tt9896916      0.0     0.0            PG         2019
#
# [747 rows x 5 columns]

# %%
release_filtered = pd.read_sql_query(q, engine)

sns.barplot(data=release_filtered, x='release_year',y='budget');

# %% [markdown]
# - The above indicates that movies released in 2018 - had more budget available than those that were released in 2019

# %% [markdown]
# - #### **Hypothesis 3:**

# %% [markdown]
# > Null Hypothesis: There is no significant difference in revenue accross the various genres.
# >
# > Alternative Hypothesis: There is a significant difference in revenue accross the various movie Genres.
# >
# > Using an alpha=.05

# %%
q = """SELECT
    g.genre_name,
    t.revenue
FROM
    extended_tmdb_data t
JOIN
    title_genres tg ON t.imdb_id = tg.tconst
JOIN
    genres g ON tg.genre_id = g.genre_id;;
"""
pd.read_sql(q, engine)
# Out:
#      genre_name     revenue
# 0        Action         0.0
# 1        Action         0.0
# 2        Action  49939800.0
# 3        Action         0.0
# 4        Action         0.0
# ...         ...         ...
# 8559      Drama         0.0
# 8560      Drama         0.0
# 8561      Drama         0.0
# 8562      Drama         0.0
# 8563      Drama         0.0
#
# [8564 rows x 2 columns]

# %%
genre = pd.read_sql_query(q, engine)

# %%
## Create groups dictionary. There are only 3 groups, but this is even more helpful when there are many groups
groups = {}
## Loop through all unique categories
for i in genre['genre_name'].unique():
    ## Get series for group and rename
    data = genre.loc[genre['genre_name']==i,'revenue'].copy()
    
    # save into the dictionary
    groups[i] = data
groups.keys()
# Out:
# dict_keys(['Action', 'Adult', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Drama', 'Family', 'Fantasy', 'History', 'Horror', 'Music', 'Musical', 'Mystery', 'Reality-TV', 'Romance', 'Sci-Fi', 'Sport', 'Thriller', 'War', 'Western'])

# %% [markdown]
# #### **Testing Assumptions - ANOVA**

# %% [markdown]
# >**Assumption of Normality**

# %%
# Filter groups with at least 8 samples
filtered_groups = {k: v for k, v in groups.items() if len(v) > 8}

# Initialize results dictionary
norm_results = {}

# Loop through filtered groups
for i, data in filtered_groups.items():
    stat, p = stats.normaltest(data)
    # Save the p val, test statistic, and the size of the group
    norm_results[i] = {'n': len(data),
                       'p': p,
                       'test stat': stat}

# Convert to a dataframe
norm_results_df = pd.DataFrame(norm_results).T
norm_results_df
# Out:
# C:\Users\Erfoxcroft\AppData\Local\anaconda3\envs\dojo-env\lib\site-packages\scipy\stats\_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=15
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                 n              p    test stat
# Action      788.0  1.353853e-200   920.428128
# Adult        15.0            NaN          NaN
# Adventure   501.0   2.628836e-99   453.978766
# Animation   268.0   3.438669e-52   236.998680
# Biography   145.0   4.803116e-49   222.514809
# Comedy     1137.0  3.685520e-290  1332.890531
# Crime       489.0  2.035717e-124   569.619407
# Drama      1841.0   0.000000e+00  3938.113010
# Family      224.0   2.042175e-77   353.170073
# Fantasy     216.0   3.188488e-54   246.360096
# History      89.0   1.577215e-22   100.402422
# Horror      839.0  6.013924e-301  1382.568071
# Music        83.0   2.317202e-30   136.474385
# Musical      37.0   3.533044e-18    80.368744
# Mystery     320.0   5.104744e-86   392.784296
# Romance     428.0  3.894096e-107   490.034287
# Sci-Fi      265.0   1.150138e-58   266.820108
# Sport        60.0   2.229406e-22    99.710274
# Thriller    745.0  4.344937e-211   968.752887
# War          42.0   1.081876e-12    55.104650
# Western      31.0   1.049512e-16    73.586073

# %%
## checking sig with pandas 
norm_results_df['sig'] = norm_results_df['p'] < .05 
norm_results_df
# Out:
#                 n              p    test stat    sig
# Action      788.0  1.353853e-200   920.428128   True
# Adult        15.0            NaN          NaN  False
# Adventure   501.0   2.628836e-99   453.978766   True
# Animation   268.0   3.438669e-52   236.998680   True
# Biography   145.0   4.803116e-49   222.514809   True
# Comedy     1137.0  3.685520e-290  1332.890531   True
# Crime       489.0  2.035717e-124   569.619407   True
# Drama      1841.0   0.000000e+00  3938.113010   True
# Family      224.0   2.042175e-77   353.170073   True
# Fantasy     216.0   3.188488e-54   246.360096   True
# History      89.0   1.577215e-22   100.402422   True
# Horror      839.0  6.013924e-301  1382.568071   True
# Music        83.0   2.317202e-30   136.474385   True
# Musical      37.0   3.533044e-18    80.368744   True
# Mystery     320.0   5.104744e-86   392.784296   True
# Romance     428.0  3.894096e-107   490.034287   True
# Sci-Fi      265.0   1.150138e-58   266.820108   True
# Sport        60.0   2.229406e-22    99.710274   True
# Thriller    745.0  4.344937e-211   968.752887   True
# War          42.0   1.081876e-12    55.104650   True
# Western      31.0   1.049512e-16    73.586073   True

# %% [markdown]
# - The SIG = True suggest that for each Genre we would reject the null hypothesis

# %% [markdown]
# >**Assumption of Equal Variance**

# %%
# with the * operator 
stats.levene(*groups.values())
# Out:
# LeveneResult(statistic=20.412695603374267, pvalue=1.2308280343726183e-75)

# %% [markdown]
# - p=value is not greater than the common significance level of 0.05. Therefore there is enough evidence to reject the null hypothesis.

# %% [markdown]
# #### **One-Way ANOVA Test**

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
## save the values as kg_lost and the labels to the Diet
values = genre['revenue']
labels = genre['genre_name']

# %%
## perform tukey's multiple comparison test and display the summary
tukeys_results = pairwise_tukeyhsd(values,labels)
tukeys_results.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# >**Visual**

# %%
plt.figure(figsize=(10, 6))  # Adjust the figsize as needed

# Rotate x-axis labels for better readability
sns.barplot(data=genre, x='genre_name', y='revenue')
plt.xticks(rotation=45, ha='right')  #rotation angle and alignment for better readability

plt.show()
